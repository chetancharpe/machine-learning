# %% [markdown]
# <a href="https://colab.research.google.com/github/chetancharpe/machine-learning/blob/main/day20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# EDA( Exploratory Data Analysis).

# %% [markdown]
# Univariate analysis

# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('/tested.csv')

# %%
df.sample()
# Out:
#      PassengerId  Survived  Pclass                         Name   Sex  Age  \
# 146         1038         0       1  Hilliard, Mr. Herbert Henry  male  NaN
#
#      SibSp  Parch Ticket     Fare Cabin Embarked
# 146      0      0  17463  51.8625   E46        S

# %% [markdown]
# 1.**Categorical Data**

# %% [markdown]
# a. countplot

# %%
# sns.countplot(df['Survived'])
df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %% [markdown]
# b.Pie chart

# %%
df['Sex'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# **2. Numerical Data**

# %% [markdown]
# a. Histogram

# %%
import matplotlib.pyplot as plt
plt.hist(df['Age'])
# Out:
# (array([16., 16., 71., 97., 43., 37., 25., 17.,  9.,  1.]),
#  array([ 0.17 ,  7.753, 15.336, 22.919, 30.502, 38.085, 45.668, 53.251,
#         60.834, 68.417, 76.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# b.Displot

# %% [markdown]
# # Skewness :In Machine Learning and Statistics, skewness measures the asymmetry of a data distribution around its mean.
#
#
# 	​

# %%
sns.distplot(df['Age'])
# Out:
# /tmp/ipykernel_1629/3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# c.Boxplot

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>
