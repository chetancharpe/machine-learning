# %% [markdown]
# <a href="https://colab.research.google.com/github/chetancharpe/machine-learning/blob/main/day19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/tested.csv')

# %% [markdown]
# 1.How Big The Data Is?

# %%
df.shape
# Out:
# (418, 12)

# %% [markdown]
# 2.How does the data look like?

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 273         1165         1       3                         Lennon, Miss. Mary
# 352         1244         0       2                        Dibden, Mr. William
# 244         1136         0       3  Johnston, Master. William Arthur Willie""
# 338         1230         0       2                       Denbury, Mr. Herbert
# 211         1103         0       3                          Finoli, Mr. Luigi
#
#         Sex   Age  SibSp  Parch              Ticket   Fare Cabin Embarked
# 273  female   NaN      1      0              370371  15.50   NaN        Q
# 352    male  18.0      0      0        S.O.C. 14879  73.50   NaN        S
# 244    male   NaN      1      2          W./C. 6607  23.45   NaN        S
# 338    male  25.0      0      0          C.A. 31029  31.50   NaN        S
# 211    male   NaN      0      0  SOTON/O.Q. 3101308   7.05   NaN        S

# %% [markdown]
# 3.What is the data type of cols?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %% [markdown]
# 4.Are there any missing values?

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# 5.How does the data lookmathematically?

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %% [markdown]
# 6.Are there duplicate values?

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# 7.How is the correlation between cols?

# %%
df.corr(numeric_only=True)['Survived']
# Out:
# PassengerId   -0.023245
# Survived       1.000000
# Pclass        -0.108615
# Age           -0.000013
# SibSp          0.099943
# Parch          0.159120
# Fare           0.191514
# Name: Survived, dtype: float64
